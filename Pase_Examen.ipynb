# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorLuna02012003/clases_de_python/blob/main/Pase_Examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint
#Funcion permite indicar quien es el ganador entre el Jugador1 y el Jugador 2
def Quien(a,b):
    if(a==b):
        print('Tie')
    elif(a>b):
        print('¡Player 1!\nWINNER!')
    else:
        print('¡Player 2!\nWINNER!')

#El diccinario se utilizo para darle un un valor a un numero
opciones = {
    1 :'Piedra',
    2 : 'Papel',
    3 : 'Tijeras',
    4 : 'Lagarto',
    5 : 'Spock',
} 
#Las variables de jugador y computadora, se utiliza para usarlo como contador
Jugador1=0
compu=0
i=1
#While me va a permitir repetir hasta que la variable i sea 3
while(i<=3):
    #Permite ingresar un numero para luego mandarlo al diccionario y darme la palabra que le corresponde a dicho numero
    #Lo mismo va para el randint, me dara un numero aleatorio indicando un rango (1,5)
    print('[1] Piedra\t[2] Papel\t[3] Tijeras\t[4] Lagarto\t[5] Spock\n')
    respuesta = int(input('Ingresa un numero: '))
    opciones[respuesta]
    CPU = randint(1,5)
    opciones[CPU]
    print(opciones[respuesta],' vs ', opciones[CPU])
    print('Ingresa Enter para continuar....')
    input()

#Las condicionales basicamente se utilizaron para saber si perdi la partida,la gane o si fue un empate
    if(opciones[respuesta]=='Piedra'):
        if(opciones[CPU]=='Piedra'):
            print('Tie')
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Papel'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Tijeras'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Lagarto'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Spock'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')

    elif(opciones[respuesta]=='Papel'):
        if(opciones[CPU]=='Papel'):
            print('Tie')
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Tijeras'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Spock'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Piedra'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Lagarto'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')

    elif(opciones[respuesta]=='Tijeras'):
        if(opciones[CPU]=='Tijeras'):
            print('Tie')
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Spock'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Papel'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Lagarto'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Piedra'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')

    elif(opciones[respuesta]=='Lagarto'):
        if(opciones[CPU]=='Lagarto'):
            print('Tie')
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Tijeras'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Spock'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Papel'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Piedra'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')
        
    elif(opciones[respuesta]=='Spock'):
        if(opciones[CPU]=='Spock'):
            print('Tie')
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Papel'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Piedra'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Tijeras'):
            print('Ganaste')
            Jugador1+=1
            print('[',Jugador1,' , ',compu,']')
        elif(opciones[CPU]=='Lagarto'):
            print('Perdiste')
            compu+=1
            print('[',Jugador1,' , ',compu,']')
    #Una vez que terminos de jugar la primera partida "i" incrementara, repitiedo el ciclo 3 veces
    i+=1
#Ejecutando la funcion para ver quien gano
Quien(Jugador1,compu)
# Out:
# [1] Piedra	[2] Papel	[3] Tijeras	[4] Lagarto	[5] Spock
#
# Ingresa un numero: 2
# Papel  vs  Tijeras
# Ingresa Enter para continuar....
#
# Perdiste
# [ 0  ,  1 ]
# [1] Piedra	[2] Papel	[3] Tijeras	[4] Lagarto	[5] Spock
#
# Ingresa un numero: 3
# Tijeras  vs  Piedra
# Ingresa Enter para continuar....
#
# Perdiste
# [ 0  ,  2 ]
# [1] Piedra	[2] Papel	[3] Tijeras	[4] Lagarto	[5] Spock
#
# Ingresa un numero: 4
# Lagarto  vs  Lagarto
# Ingresa Enter para continuar....
#
# Tie
# [ 0  ,  2 ]
# ¡Player 2!
# WINNER!
